# %%
#dbutils.fs.mkdirs("/FileStore/f1")

# %%
races_df = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .load("/Volumes/workspace/f1_proje/f1_data/The_Race.csv")

# %%
races_df.select('year')
# Out:
# DataFrame[year: int]

# %%
#display(races_df['year'])

# %%
races_df['year'].dtype
# Out:
# Column<'year['dtype']'>

# %%
#races_df.rdd.getNumPartitions()  # Not supported in serverless, consider using DataFrame API to get partition info

# %%
races_df.write.format("delta")\
.mode("overwrite")\
.save("/Volumes/workspace/f1_proje/f1_data/races.delta")

# %%
bronze_df=spark.read.format("delta")\
.load("/Volumes/workspace/f1_proje/f1_data/races.delta")
#display(bronze_df)

# %%
#display(bronze_df.limit(1))

# %%
races_df.write.format("delta")

# %%
#display(races_df.limit(2))

# %%
races_df = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .load("/Volumes/workspace/f1_proje/f1_data/The_Race.csv")
races_df=races_df.replace("\\N", None)

# %%
drivers_df = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .load("/Volumes/workspace/f1_proje/f1_data/The_Driver.csv")
drivers_df=drivers_df.replace("\\N", None)

# %%
results_df = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .load("/Volumes/workspace/f1_proje/f1_data/The_Result.csv")
results_df = results_df.replace("\\N", None)

# %%
constructors_df = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .load("/Volumes/workspace/f1_proje/f1_data/The_Constructor.csv")
constructors_df = constructors_df.replace("\\N", None)

# %%
#display(races_df.limit(1))
#display(drivers_df.limit(1))
#display(results_df.limit(1))
#display(constructors_df.limit(1))

# %%
dbutils.fs.mkdirs("/Volumes/workspace/f1_proje/f1_data/bronze")
# Out:
# True

# %%
races_df.write.format("delta") \
.mode("overwrite")\
.save("/Volumes/workspace/f1_proje/f1_data/bronze/races")

# %%
drivers_df.write.format("delta") \
    .mode("overwrite") \
    .save("/Volumes/workspace/f1_proje/f1_data/bronze/drivers")

# %%
results_df.write.format("delta") \
    .mode("overwrite") \
    .save("/Volumes/workspace/f1_proje/f1_data/bronze/results")

# %%
constructors_df.write.format("delta") \
    .mode("overwrite") \
    .save("/Volumes/workspace/f1_proje/f1_data/bronze/constructors")

# %%
bronze_races_df = spark.read.format("delta") \
    .load("/Volumes/workspace/f1_proje/f1_data/bronze/races")

# %%
#A limpeza dos Dados parte da Silver#

# %%
#display(bronze_df.limit(1))

# %%
#display(bronze_races_df.limit(1))

# %%
from pyspark.sql.functions import year, col

silver_races_df = bronze_races_df \
    .withColumn(
        "Ano_corrida",        
         year(col("date"))) \
        .drop("url")

# %%
#display(silver_races_df.limit(1))

# %%
#silver_races_df.write.format("delta") \
  #  .mode("overwrite") \
   # .save("/Volumes/workspace/f1_proje/f1_data/silver/races")

# %%
bronze_drivers_df = spark.read.format("delta") \
    .load("/Volumes/workspace/f1_proje/f1_data/bronze/drivers")

# %%
bronze_results_df = spark.read.format("delta") \
    .load("/Volumes/workspace/f1_proje/f1_data/bronze/results")

# %%
bronze_constructors_df = spark.read.format("delta") \
    .load("/Volumes/workspace/f1_proje/f1_data/bronze/constructors")

# %%
joined_df = bronze_results_df.join(
    bronze_drivers_df,
    bronze_results_df.driverId == bronze_drivers_df.driverId
)

# %%
#Pd = races_df.limit(10).toPandas()

# %%
#display(Pd)

# %%
joined_df
# Out:
# DataFrame[resultId: int, raceId: int, driverId: int, constructorId: int, number: string, grid: int, position: string, positionText: string, positionOrder: int, points: double, laps: int, time: string, milliseconds: string, fastestLap: string, rank: string, fastestLapTime: string, fastestLapSpeed: string, statusId: int, driverId: int, driverRef: string, number: string, code: string, forename: string, surname: string, dob: date, nationality: string, url: string]

# %%
bronze_results_df.driverId == bronze_drivers_df.driverId
# Out:
# Column<'==(driverId, driverId)'>

# %%
joined_df.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Join Inner, '`==`('driverId, 'driverId)
# :- Relation [resultId#32625,raceId#32626,driverId#32627,constructorId#32628,number#32629,grid#32630,position#32631,positionText#32632,positionOrder#32633,points#32634,laps#32635,time#32636,milliseconds#32637,fastestLap#32638,rank#32639,fastestLapTime#32640,fastestLapSpeed#32641,statusId#32642] parquet
# +- Relation [driverId#32615,driverRef#32616,number#32617,code#32618,forename#32619,surname#32620,dob#32621,nationality#32622,url#32623] parquet
#
# == Analyzed Logical Plan ==
# resultId: int, raceId: int, driverId: int, constructorId: int, number: string, grid: int, position: string, positionText: string, positionOrder: int, points: double, laps: int, time: string, milliseconds: string, fastestLap: string, rank: string, fastestLapTime: string, fastestLapSpeed: string, statusId: int, driverId: int, driverRef: string, number: string, code: string, forename: string, surname: string, dob: date, ... 2 more fields
# Join Inner, (driverId#32627 = driverId#32615)
# :- Relation [resultId#32625,raceId#32626,driverId#32627,constructorId#32628,number#32629,grid#32630,position#32631,positionText#32632,positionOrder#32633,points#32634,laps#32635,time#32636,milliseconds#32637,fastestLap#32638,rank#32639,fastestLapTime#32640,fastestLapSpeed#32641,statusId#32642] parquet
# +- Relation [driverId#32615,driverRef#32616,number#32617,code#32618,forename#32619,surname#32620,dob#32621,nationality#32622,url#32623] parquet
#
# == Optimized Logical Plan ==
# Join Inner, (driverId#32627 = driverId#32615)
# :- Filter isnotnull(driverId#32627)
# :  +- Relation [resultId#32625,raceId#32626,driverId#32627,constructorId#32628,number#32629,grid#32630,position#32631,positionText#32632,positionOrder#32633,points#32634,laps#32635,time#32636,milliseconds#32637,fastestLap#32638,rank#32639,fastestLapTime#32640,fastestLapSpeed#32641,statusId#32642] parquet
# +- Filter isnotnull(driverId#32615)
#    +- Relation [driverId#32615,driverRef#32616,number#32617,code#32618,forename#32619,surname#32620,dob#32621,nationality#32622,url#32623] parquet
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    PhotonResultStage
#    +- PhotonColumnarToRow
#       +- PhotonBroadcastHashJoin [driverId#32627], [driverId#32615], Inner, BuildRight, false, true
#          :- PhotonScan parquet [resultId#32625,raceId#32626,driverId#32627,constructorId#32628,number#32629,grid#32630,position#32631,positionText#32632,positionOrder#32633,points#32634,laps#32635,time#32636,milliseconds#32637,fastestLap#32638,rank#32639,fastestLapTime#32640,fastestLapSpeed#32641,statusId#32642] DataFilters: [isnotnull(driverId#32627)], DictionaryFilters: [], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[dbfs:/Volumes/workspace/f1_proje/f1_data/bronze/results], OptionalDataFilters: [hashedrelationcontains(driverId#32627)], PartitionFilters: [], ReadSchema: struct<resultId:int,raceId:int,driverId:int,constructorId:int,number:string,grid:int,position:str..., RequiredDataFilters: [isnotnull(driverId#32627)]
#          +- PhotonShuffleExchangeSource
#             +- PhotonShuffleMapStage EXECUTOR_BROADCAST, [id=#26889]
#                +- PhotonShuffleExchangeSink SinglePartition
#                   +- PhotonScan parquet [driverId#32615,driverRef#32616,number#32617,code#32618,forename#32619,surname#32620,dob#32621,nationality#32622,url#32623] DataFilters: [isnotnull(driverId#32615)], DictionaryFilters: [], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[dbfs:/Volumes/workspace/f1_proje/f1_data/bronze/drivers], OptionalDataFilters: [], PartitionFilters: [], ReadSchema: struct<driverId:int,driverRef:string,number:string,code:string,forename:string,surname:string,dob..., RequiredDataFilters: [isnotnull(driverId#32615)]
#
# == Photon Explanation ==
# The query is fully supported by Photon.

# %%
#display(joined_df)

# %%
joined_df = bronze_results_df.join(
    bronze_drivers_df,
    bronze_results_df.driverId == bronze_drivers_df.driverId
)

# %%
#display(joined_df)

# %%
clean_joined_df = joined_df.select(
    bronze_results_df.raceId,
    bronze_drivers_df.forename,
    bronze_drivers_df.surname,
    bronze_results_df.position,
    bronze_results_df.points
)

# %%
#display(clean_joined_df)

# %%
clean_joined_df = joined_df.select(
    bronze_results_df.raceId,
    bronze_drivers_df.forename,
    bronze_drivers_df.surname,
    bronze_results_df.position,
    bronze_results_df.points
)

# %%
from pyspark.sql.functions import *

clean_joined_df = clean_joined_df.withColumn(
    "Piloto",
    concat(
        col("forename"),
        lit(" "),
        col("surname")
    )
)

# %%
display(clean_joined_df.limit(1))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>raceId</th><th>forename</th><th>surname</th><th>position</th><th>points</th><th>Piloto</th></tr></thead><tbody><tr><td>18</td><td>Lewis</td><td>Hamilton</td><td>1</td><td>10.0</td><td>Lewis Hamilton</td></tr></tbody></table></div>

# %%
silver_drivers_df = spark.read.format("delta") \
    .load("/Volumes/workspace/f1_proje/f1_data/silver/drivers")

# %%
#display(silver_drivers_df)

# %%
spark.read.format("delta")

# %%
from pyspark.sql.functions import *

silver_drivers_df = bronze_drivers_df.withColumn(
    "driver_name",
    concat(
        col("forename"),
        lit(" "),
        col("surname") 
    )
).drop("url")

# %%
#display(silver_drivers_df.limit(1))

# %%
from pyspark.sql.functions import sum

# %%
gold_driver_points_df = clean_joined_df.groupBy(
    "Piloto"
).agg(
    sum("points").alias("total_pontos")
)

# %%
#display(gold_driver_points_df)

# %%
ranking_df=gold_driver_points_df.orderBy(
    col("total_pontos").desc()
)

# %%
#display(ranking_df)

# %%
ranking_df.write.format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save("/Volumes/workspace/f1_proje/f1_data/gold/driver_ranking")

# %%
print(spark,version)
# Out:
# <pyspark.sql.connect.session.SparkSession object at 0xff39b62db260> <function version at 0xff3a0c2a8cc0>

# %%
from pyspark.sql.functions import col, desc


ranking_df=gold_driver_points_df \
    .filter(col("total_pontos") > 0) \
     .orderBy(desc("total_pontos"))

# %%
#display(ranking_df)

# %%
bronze_constructors_df=spark.read.format("delta").load("/Volumes/workspace/f1_proje/f1_data/bronze/constructors")

# %%
silver_constructors_df=bronze_constructors_df \
    .withColumnRenamed("name", "constructor_name") \
    .drop("url")

# %%
#display(silver_constructors_df)

# %%
silver_constructors_df.write.format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save("/Volumes/workspace/f1_proje/f1_data/silver/constructors")

# %%
bronze_results_df=spark.read.format("delta") \
    .load("/Volumes/workspace/f1_proje/f1_data/bronze/results")

# %%
#display(bronze_results_df.limit(1))

# %%
silver_results_df=bronze_results_df \
    .drop("statusId") \
    .withColumnRenamed("points", "total_pontos") \

# %%
#display(silver_results_df.limit(1))

# %%
silver_results_df.write.format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save("/Volumes/workspace/f1_proje/f1_data/silver/results")

# %%
#display(silver_results_df.limit(1))

# %%
dbutils.fs.ls("/Volumes/workspace/f1_proje/f1_data/silver/results")



#display(silver_results_df.limit(1))
# Out:
# [FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/_delta_log/', name='_delta_log/', size=0, modificationTime=1778698135975),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-06010e8b-8d7e-4aaa-95a7-a9e4db194039.c000.snappy.parquet', name='part-00000-06010e8b-8d7e-4aaa-95a7-a9e4db194039.c000.snappy.parquet', size=469725, modificationTime=1778697314000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-0a16fdcc-c6cd-4b23-a0c3-9371dc7ddb16.c000.snappy.parquet', name='part-00000-0a16fdcc-c6cd-4b23-a0c3-9371dc7ddb16.c000.snappy.parquet', size=517524, modificationTime=1778685839000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-123348c8-df3e-42dd-b843-058abfb582fa.c000.snappy.parquet', name='part-00000-123348c8-df3e-42dd-b843-058abfb582fa.c000.snappy.parquet', size=535529, modificationTime=1778685928000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-142214c4-1cde-4b30-b09b-cf8b3e9ca0eb.c000.snappy.parquet', name='part-00000-142214c4-1cde-4b30-b09b-cf8b3e9ca0eb.c000.snappy.parquet', size=487730, modificationTime=1778695795000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-1cda67bd-c662-4826-8c33-5692f353c4c0.c000.snappy.parquet', name='part-00000-1cda67bd-c662-4826-8c33-5692f353c4c0.c000.snappy.parquet', size=535529, modificationTime=1778685093000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-2ae3f54d-c4c1-4124-b291-864f4e837f0a.c000.snappy.parquet', name='part-00000-2ae3f54d-c4c1-4124-b291-864f4e837f0a.c000.snappy.parquet', size=487730, modificationTime=1778697329000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-3aa930ac-f4a7-4e0a-ad0d-e70f85969606.c000.snappy.parquet', name='part-00000-3aa930ac-f4a7-4e0a-ad0d-e70f85969606.c000.snappy.parquet', size=469725, modificationTime=1778695565000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-3c757ad8-600c-4a64-8891-6c137954e748.c000.snappy.parquet', name='part-00000-3c757ad8-600c-4a64-8891-6c137954e748.c000.snappy.parquet', size=517524, modificationTime=1778630435000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-413abe35-2563-41d3-a3e2-e252cbe711f6.c000.snappy.parquet', name='part-00000-413abe35-2563-41d3-a3e2-e252cbe711f6.c000.snappy.parquet', size=517524, modificationTime=1778680896000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-5942874d-15f7-43b8-863f-b4ddc6577ff3.c000.snappy.parquet', name='part-00000-5942874d-15f7-43b8-863f-b4ddc6577ff3.c000.snappy.parquet', size=487730, modificationTime=1778695587000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-5df24144-7a8e-4bab-921e-a2ec0b1d85ea.c000.snappy.parquet', name='part-00000-5df24144-7a8e-4bab-921e-a2ec0b1d85ea.c000.snappy.parquet', size=535529, modificationTime=1778624296000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-5e4aaf46-a077-4bb5-95f9-a9980181743f.c000.snappy.parquet', name='part-00000-5e4aaf46-a077-4bb5-95f9-a9980181743f.c000.snappy.parquet', size=535529, modificationTime=1778680923000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-65a02ce5-b995-4bd7-85fc-d9a9ce594a60.c000.snappy.parquet', name='part-00000-65a02ce5-b995-4bd7-85fc-d9a9ce594a60.c000.snappy.parquet', size=487730, modificationTime=1778696447000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-7351b23a-5807-4961-8fac-b7d0bb83c31d.c000.snappy.parquet', name='part-00000-7351b23a-5807-4961-8fac-b7d0bb83c31d.c000.snappy.parquet', size=517524, modificationTime=1778623177000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-73de3958-642a-4b19-8eb8-6a1a6b1a3360.c000.snappy.parquet', name='part-00000-73de3958-642a-4b19-8eb8-6a1a6b1a3360.c000.snappy.parquet', size=517524, modificationTime=1778684905000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-86600b76-9840-4db3-92a9-3b8d3d87c7bd.c000.snappy.parquet', name='part-00000-86600b76-9840-4db3-92a9-3b8d3d87c7bd.c000.snappy.parquet', size=517524, modificationTime=1778680903000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-8dfc0efa-54f1-4252-bc8f-61eb6fcd1161.c000.snappy.parquet', name='part-00000-8dfc0efa-54f1-4252-bc8f-61eb6fcd1161.c000.snappy.parquet', size=517524, modificationTime=1778682682000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-9523bfdb-9643-48e8-8ccb-494132eb9bfe.c000.snappy.parquet', name='part-00000-9523bfdb-9643-48e8-8ccb-494132eb9bfe.c000.snappy.parquet', size=535529, modificationTime=1778630530000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-a58063fc-1f55-4958-8b37-a1d8d58bb128.c000.snappy.parquet', name='part-00000-a58063fc-1f55-4958-8b37-a1d8d58bb128.c000.snappy.parquet', size=487730, modificationTime=1778696864000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-ae89eea8-db87-4486-b539-68641f50d06e.c000.snappy.parquet', name='part-00000-ae89eea8-db87-4486-b539-68641f50d06e.c000.snappy.parquet', size=487730, modificationTime=1778696087000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-b260525d-6a2c-40ab-ab90-dc205c3a6728.c000.snappy.parquet', name='part-00000-b260525d-6a2c-40ab-ab90-dc205c3a6728.c000.snappy.parquet', size=469725, modificationTime=1778698135000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-bf01d368-5cde-4bf3-af15-acdf68211c33.c000.snappy.parquet', name='part-00000-bf01d368-5cde-4bf3-af15-acdf68211c33.c000.snappy.parquet', size=535529, modificationTime=1778682770000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-c72c9d53-d9de-4b58-a351-04612835194a.c000.snappy.parquet', name='part-00000-c72c9d53-d9de-4b58-a351-04612835194a.c000.snappy.parquet', size=517506, modificationTime=1778622268000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-e03add33-607d-45ea-905f-d7778f02952c.c000.snappy.parquet', name='part-00000-e03add33-607d-45ea-905f-d7778f02952c.c000.snappy.parquet', size=469725, modificationTime=1778696045000),
#  FileInfo(path='dbfs:/Volumes/workspace/f1_proje/f1_data/silver/results/part-00000-ea2f9117-7361-44c1-9c99-a7247ce46412.c000.snappy.parquet', name='part-00000-ea2f9117-7361-44c1-9c99-a7247ce46412.c000.snappy.parquet', size=517524, modificationTime=1778682697000)]

# %%
bronze_drivers_df = spark.read.format("delta") \
    .load("/Volumes/workspace/f1_proje/f1_data/bronze/drivers")

# %%
silver_drivers_df = bronze_drivers_df \
    .withColumnRenamed("forename", "nome") \
    .withColumnRenamed("surname", "sobrenome") \
    .drop("url")

# %%
#display(silver_drivers_df.limit(1))

# %%
silver_drivers_df.write.format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save("/Volumes/workspace/f1_proje/f1_data/silver/drivers")

# %%
# Bronze  -> dados brutos
# Silver  -> limpeza e transformação
# Gold    -> análises de negócio

# %%
silver_drivers_df.write.format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save("/Volumes/workspace/f1_proje/f1_data/silver/drivers")

# %%
bronze_drivers_df = spark.read.format("delta") \
    .load("/Volumes/workspace/f1_proje/f1_data/bronze/drivers")

silver_drivers_df = bronze_drivers_df \
    .withColumnRenamed("forename", "nome") \
    .withColumnRenamed("surname", "sobrenome") \
    .drop("url")

silver_drivers_df.write.format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save("/Volumes/workspace/f1_proje/f1_data/silver/drivers")

# %%
#display(silver_drivers_df.limit(1))

# %%
bronze_races_df = spark.read.format("delta") \
    .load("/Volumes/workspace/f1_proje/f1_data/bronze/races")

silver_races_df = bronze_races_df \
    .withColumnRenamed("year", "ano_corrida") \
     .drop("url")   

silver_races_df.write.format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save("/Volumes/workspace/f1_proje/f1_data/silver/races")

# %%
#display(silver_races_df.limit(1))

# %%
bronze_results_df = spark.read.format("delta") \
    .load("/Volumes/workspace/f1_proje/f1_data/bronze/results")

silver_results_df = bronze_results_df \
    .withColumnRenamed("points", "total_pontos")

silver_results_df.write.format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save("/Volumes/workspace/f1_proje/f1_data/silver/results")

# %%
#display(silver_results_df.limit(1))

# %%
bronze_constructors_df = spark.read.format("delta") \
    .load("/Volumes/workspace/f1_proje/f1_data/bronze/constructors")

silver_constructors_df = bronze_constructors_df \
    .withColumnRenamed("name", "nome") \
    .withColumnRenamed("nationality", "nacionalidade") \
    .drop("url")
silver_constructors_df.write.format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save("/Volumes/workspace/f1_proje/f1_data/silver/constructors")

# %%
#display(silver_constructors_df.limit(1 ))

# %%
from pyspark.sql.functions import sum, col

silver_results_df = spark.read.format("delta") \
    .load("/Volumes/workspace/f1_proje/f1_data/silver/results")

silver_drivers_df = spark.read.format("delta") \
    .load("/Volumes/workspace/f1_proje/f1_data/silver/drivers")

# %%
gold_driver_ranking_df = silver_results_df.groupBy("driverId") \
    .agg(sum("total_pontos").alias("pontuacao_total"))

# %%
#display(gold_driver_ranking_df.limit(1))

# %%
gold_driver_ranking_df = gold_driver_ranking_df.join(
    silver_drivers_df,
    on="driverId",
    how="inner"
)

# %%
gold_driver_ranking_df = gold_driver_ranking_df.orderBy(
    col("pontuacao_total").desc()
)

# %%
#display(gold_driver_ranking_df.limit(1))

# %%
#display(gold_driver_ranking_df)

# %%
gold_driver_ranking_df.write.format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save("/Volumes/workspace/f1_proje/f1_data/gold/driver_ranking")

# %%
silver_results_df = spark.read.format("delta") \
    .load("/Volumes/workspace/f1_proje/f1_data/silver/results")

# %%
silver_constructors_df = spark.read.format("delta") \
    .load("/Volumes/workspace/f1_proje/f1_data/silver/constructors")

# %%
silver_constructors_df = bronze_constructors_df.drop("url")

# %%
#display(silver_constructors_df.limit(1))

# %%
from  pyspark.sql.functions import sum, col

# %%
gold_constructor_ranking_df = silver_results_df.groupBy("constructorId") \
    .agg(sum("total_pontos").alias("pontuacao_total"))

# %%
gold_constructor_ranking_df = gold_constructor_ranking_df.join(
    silver_constructors_df,
    on="constructorId",
    how="inner"
)

# %%
gold_constructor_ranking_df = gold_constructor_ranking_df.orderBy(
    col("pontuacao_total").desc()
)

# %%
#display(gold_constructor_ranking_df)

# %%
gold_constructor_ranking_df.write.format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save("/Volumes/workspace/f1_proje/f1_data/gold/constructor_ranking")

# %%
from  pyspark.sql.functions import count

gold_races_year_df = silver_races_df.groupBy("ano_corrida") \
    .agg(count("raceId").alias("total_corridas"))

display(gold_races_year_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ano_corrida</th><th>total_corridas</th></tr></thead><tbody><tr><td>2004</td><td>18</td></tr><tr><td>1996</td><td>16</td></tr><tr><td>2008</td><td>18</td></tr><tr><td>2006</td><td>18</td></tr><tr><td>1991</td><td>16</td></tr><tr><td>1990</td><td>16</td></tr><tr><td>1992</td><td>16</td></tr><tr><td>1981</td><td>15</td></tr><tr><td>1973</td><td>15</td></tr><tr><td>1970</td><td>13</td></tr><tr><td>1952</td><td>8</td></tr><tr><td>1987</td><td>16</td></tr><tr><td>1983</td><td>15</td></tr><tr><td>1975</td><td>14</td></tr><tr><td>2022</td><td>22</td></tr><tr><td>2009</td><td>17</td></tr><tr><td>2003</td><td>16</td></tr><tr><td>1999</td><td>16</td></tr><tr><td>1980</td><td>14</td></tr><tr><td>2005</td><td>19</td></tr><tr><td>2001</td><td>17</td></tr><tr><td>1995</td><td>17</td></tr><tr><td>2011</td><td>19</td></tr><tr><td>2014</td><td>19</td></tr><tr><td>1985</td><td>16</td></tr><tr><td>1966</td><td>9</td></tr><tr><td>1961</td><td>8</td></tr><tr><td>1994</td><td>16</td></tr><tr><td>1989</td><td>16</td></tr><tr><td>1976</td><td>16</td></tr><tr><td>1974</td><td>15</td></tr><tr><td>1959</td><td>9</td></tr><tr><td>2000</td><td>17</td></tr><tr><td>1964</td><td>10</td></tr><tr><td>1963</td><td>10</td></tr><tr><td>2015</td><td>19</td></tr><tr><td>2019</td><td>21</td></tr><tr><td>2010</td><td>19</td></tr><tr><td>1971</td><td>11</td></tr><tr><td>1967</td><td>11</td></tr><tr><td>1958</td><td>11</td></tr><tr><td>1957</td><td>8</td></tr><tr><td>2016</td><td>21</td></tr><tr><td>2017</td><td>20</td></tr><tr><td>1986</td><td>16</td></tr><tr><td>1979</td><td>15</td></tr><tr><td>1978</td><td>16</td></tr><tr><td>1968</td><td>12</td></tr><tr><td>1950</td><td>7</td></tr><tr><td>2023</td><td>22</td></tr><tr><td>1977</td><td>17</td></tr><tr><td>1969</td><td>11</td></tr><tr><td>1956</td><td>8</td></tr><tr><td>2007</td><td>17</td></tr><tr><td>1997</td><td>17</td></tr><tr><td>1988</td><td>16</td></tr><tr><td>1982</td><td>16</td></tr><tr><td>1965</td><td>10</td></tr><tr><td>1954</td><td>9</td></tr><tr><td>2012</td><td>20</td></tr><tr><td>2021</td><td>22</td></tr><tr><td>1998</td><td>16</td></tr><tr><td>1993</td><td>16</td></tr><tr><td>1962</td><td>9</td></tr><tr><td>1955</td><td>7</td></tr><tr><td>2020</td><td>17</td></tr><tr><td>2002</td><td>17</td></tr><tr><td>1984</td><td>16</td></tr><tr><td>1972</td><td>12</td></tr><tr><td>1960</td><td>10</td></tr><tr><td>1953</td><td>9</td></tr><tr><td>1951</td><td>8</td></tr><tr><td>2013</td><td>19</td></tr><tr><td>2018</td><td>21</td></tr><tr><td>2024</td><td>24</td></tr></tbody></table></div>

# %%
gold_races_year_df.write.format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save("/Volumes/workspace/f1_proje/f1_data/gold/races_by_year")

# %%
gold_driver_wins_df = silver_results_df.filter(
    silver_results_df.position == 1
)

# %%
gold_driver_wins_df = gold_driver_wins_df.groupBy("driverId") \
    .agg(count("raceId").alias("vitorias"))

# %%
gold_driver_wins_df = gold_driver_wins_df.join(
    silver_drivers_df,
    on="driverId",
    how="inner"
)

# %%
gold_driver_country_df = silver_drivers_df.groupBy("nationality") \
    .agg(count("driverId").alias("quantidade_pilotos"))

# %%
print(gold_driver_country_df)
# Out:
# DataFrame[nationality: string, quantidade_pilotos: bigint]

# %%
# %sql

Select *
FROM delta.`/Volumes/workspace/f1_proje/f1_data/gold/driver_ranking`
ORDER BY pontuacao_total DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>driverId</th><th>pontuacao_total</th><th>driverRef</th><th>number</th><th>code</th><th>nome</th><th>sobrenome</th><th>dob</th><th>nationality</th></tr></thead><tbody><tr><td>1</td><td>4820.5</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td></tr><tr><td>20</td><td>3098.0</td><td>vettel</td><td>5</td><td>VET</td><td>Sebastian</td><td>Vettel</td><td>1987-07-03</td><td>German</td></tr><tr><td>830</td><td>2912.5</td><td>max_verstappen</td><td>33</td><td>VER</td><td>Max</td><td>Verstappen</td><td>1997-09-30</td><td>Dutch</td></tr><tr><td>4</td><td>2329.0</td><td>alonso</td><td>14</td><td>ALO</td><td>Fernando</td><td>Alonso</td><td>1981-07-29</td><td>Spanish</td></tr><tr><td>8</td><td>1873.0</td><td>raikkonen</td><td>7</td><td>RAI</td><td>Kimi</td><td>Räikkönen</td><td>1979-10-17</td><td>Finnish</td></tr><tr><td>822</td><td>1788.0</td><td>bottas</td><td>77</td><td>BOT</td><td>Valtteri</td><td>Bottas</td><td>1989-08-28</td><td>Finnish</td></tr><tr><td>3</td><td>1594.5</td><td>rosberg</td><td>6</td><td>ROS</td><td>Nico</td><td>Rosberg</td><td>1985-06-27</td><td>German</td></tr><tr><td>815</td><td>1585.0</td><td>perez</td><td>11</td><td>PER</td><td>Sergio</td><td>Pérez</td><td>1990-01-26</td><td>Mexican</td></tr><tr><td>30</td><td>1566.0</td><td>michael_schumacher</td><td>null</td><td>MSC</td><td>Michael</td><td>Schumacher</td><td>1969-01-03</td><td>German</td></tr><tr><td>844</td><td>1363.0</td><td>leclerc</td><td>16</td><td>LEC</td><td>Charles</td><td>Leclerc</td><td>1997-10-16</td><td>Monegasque</td></tr><tr><td>817</td><td>1320.0</td><td>ricciardo</td><td>3</td><td>RIC</td><td>Daniel</td><td>Ricciardo</td><td>1989-07-01</td><td>Australian</td></tr><tr><td>18</td><td>1235.0</td><td>button</td><td>22</td><td>BUT</td><td>Jenson</td><td>Button</td><td>1980-01-19</td><td>British</td></tr><tr><td>832</td><td>1203.5</td><td>sainz</td><td>55</td><td>SAI</td><td>Carlos</td><td>Sainz</td><td>1994-09-01</td><td>Spanish</td></tr><tr><td>13</td><td>1167.0</td><td>massa</td><td>19</td><td>MAS</td><td>Felipe</td><td>Massa</td><td>1981-04-25</td><td>Brazilian</td></tr><tr><td>17</td><td>1047.5</td><td>webber</td><td>null</td><td>WEB</td><td>Mark</td><td>Webber</td><td>1976-08-27</td><td>Australian</td></tr><tr><td>846</td><td>950.0</td><td>norris</td><td>4</td><td>NOR</td><td>Lando</td><td>Norris</td><td>1999-11-13</td><td>British</td></tr><tr><td>117</td><td>798.5</td><td>prost</td><td>null</td><td>null</td><td>Alain</td><td>Prost</td><td>1955-02-24</td><td>French</td></tr><tr><td>847</td><td>664.0</td><td>russell</td><td>63</td><td>RUS</td><td>George</td><td>Russell</td><td>1998-02-15</td><td>British</td></tr><tr><td>22</td><td>658.0</td><td>barrichello</td><td>null</td><td>BAR</td><td>Rubens</td><td>Barrichello</td><td>1972-05-23</td><td>Brazilian</td></tr><tr><td>102</td><td>614.0</td><td>senna</td><td>null</td><td>null</td><td>Ayrton</td><td>Senna</td><td>1960-03-21</td><td>Brazilian</td></tr><tr><td>807</td><td>563.0</td><td>hulkenberg</td><td>27</td><td>HUL</td><td>Nico</td><td>Hülkenberg</td><td>1987-08-19</td><td>German</td></tr><tr><td>14</td><td>535.0</td><td>coulthard</td><td>null</td><td>COU</td><td>David</td><td>Coulthard</td><td>1971-03-27</td><td>British</td></tr><tr><td>137</td><td>485.5</td><td>piquet</td><td>null</td><td>null</td><td>Nelson</td><td>Piquet</td><td>1952-08-17</td><td>Brazilian</td></tr><tr><td>95</td><td>482.0</td><td>mansell</td><td>null</td><td>null</td><td>Nigel</td><td>Mansell</td><td>1953-08-08</td><td>British</td></tr><tr><td>839</td><td>440.0</td><td>ocon</td><td>31</td><td>OCO</td><td>Esteban</td><td>Ocon</td><td>1996-09-17</td><td>French</td></tr><tr><td>842</td><td>426.0</td><td>gasly</td><td>10</td><td>GAS</td><td>Pierre</td><td>Gasly</td><td>1996-02-07</td><td>French</td></tr><tr><td>182</td><td>420.5</td><td>lauda</td><td>nul ...

# %%
# %sql
Select nome,
       sobrenome,
       pontuacao_total
FROM delta.`/Volumes/workspace/f1_proje/f1_data/gold/driver_ranking`
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>nome</th><th>sobrenome</th><th>pontuacao_total</th></tr></thead><tbody><tr><td>Lewis</td><td>Hamilton</td><td>4820.5</td></tr><tr><td>Sebastian</td><td>Vettel</td><td>3098.0</td></tr><tr><td>Max</td><td>Verstappen</td><td>2912.5</td></tr><tr><td>Fernando</td><td>Alonso</td><td>2329.0</td></tr><tr><td>Kimi</td><td>Räikkönen</td><td>1873.0</td></tr><tr><td>Valtteri</td><td>Bottas</td><td>1788.0</td></tr><tr><td>Nico</td><td>Rosberg</td><td>1594.5</td></tr><tr><td>Sergio</td><td>Pérez</td><td>1585.0</td></tr><tr><td>Michael</td><td>Schumacher</td><td>1566.0</td></tr><tr><td>Charles</td><td>Leclerc</td><td>1363.0</td></tr></tbody></table></div>

# %%
# %sql
SELECT 
*
FROM delta.`/Volumes/workspace/f1_proje/f1_data/gold/constructor_ranking`
ORDER BY pontuacao_total DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>constructorId</th><th>pontuacao_total</th><th>constructorRef</th><th>name</th><th>nationality</th></tr></thead><tbody><tr><td>6</td><td>11091.27</td><td>ferrari</td><td>Ferrari</td><td>Italian</td></tr><tr><td>131</td><td>7730.639999999999</td><td>mercedes</td><td>Mercedes</td><td>German</td></tr><tr><td>9</td><td>7673.0</td><td>red_bull</td><td>Red Bull</td><td>Austrian</td></tr><tr><td>1</td><td>7022.5</td><td>mclaren</td><td>McLaren</td><td>British</td></tr><tr><td>3</td><td>3641.0</td><td>williams</td><td>Williams</td><td>British</td></tr><tr><td>4</td><td>1777.0</td><td>renault</td><td>Renault</td><td>French</td></tr><tr><td>10</td><td>1098.0</td><td>force_india</td><td>Force India</td><td>Indian</td></tr><tr><td>32</td><td>995.0</td><td>team_lotus</td><td>Team Lotus</td><td>British</td></tr><tr><td>22</td><td>861.5</td><td>benetton</td><td>Benetton</td><td>Italian</td></tr><tr><td>25</td><td>711.0</td><td>tyrrell</td><td>Tyrrell</td><td>British</td></tr><tr><td>208</td><td>706.0</td><td>lotus_f1</td><td>Lotus F1</td><td>British</td></tr><tr><td>34</td><td>631.0</td><td>brabham</td><td>Brabham</td><td>British</td></tr><tr><td>15</td><td>561.0</td><td>sauber</td><td>Sauber</td><td>Swiss</td></tr><tr><td>66</td><td>537.5</td><td>brm</td><td>BRM</td><td>British</td></tr><tr><td>5</td><td>500.0</td><td>toro_rosso</td><td>Toro Rosso</td><td>Italian</td></tr><tr><td>214</td><td>498.0</td><td>alpine</td><td>Alpine F1 Team</td><td>French</td></tr><tr><td>117</td><td>492.0</td><td>aston_martin</td><td>Aston Martin</td><td>British</td></tr><tr><td>27</td><td>388.0</td><td>ligier</td><td>Ligier</td><td>French</td></tr><tr><td>51</td><td>361.0</td><td>alfa</td><td>Alfa Romeo</td><td>Swiss</td></tr><tr><td>170</td><td>336.5</td><td>cooper-climax</td><td>Cooper-Climax</td><td>British</td></tr><tr><td>105</td><td>313.14</td><td>maserati</td><td>Maserati</td><td>Italian</td></tr><tr><td>2</td><td>308.0</td><td>bmw_sauber</td><td>BMW Sauber</td><td>German</td></tr><tr><td>213</td><td>306.0</td><td>alphatauri</td><td>AlphaTauri</td><td>Italian</td></tr><tr><td>210</td><td>293.0</td><td>haas</td><td>Haas F1 Team</td><td>American</td></tr><tr><td>17</td><td>291.0</td><td>jordan</td><td>Jordan</td><td>Irish</td></tr><tr><td>211</td><td>283.0</td><td>racing_point</td><td>Racing Point</td><td>British</td></tr><tr><td>172</td><td>281.0</td><td>lotus-climax</td><td>Lotus-Climax</td><td>British</td></tr><tr><td>7</td><td>278.5</td><td>toyota</td><td>Toyota</td><td>Japanese</td></tr><tr><td>16</td><td>227.0</td><td>bar</td><td>BAR</td><td>British</td></tr><tr><td>180</td><td>209.0</td><td>lotus-ford</td><td>Lotus-Ford</td><td>British</td></tr><tr><td>191</td><td>175.0</td><td>brabham-repco</td><td>Brabham-Repco</td><td>British</td></tr><tr><td>23</td><td>172.0</td><td>brawn</td><td>Brawn</td><td>British</td></tr><tr><td>11</td><td>156.0</td><td>honda</td><td>Honda</td><td>Japanese</td></tr><tr><td>37</td><td>148.0</td><td>march</td><td>March</td><td>British</td></tr><tr><td>187</td><td>143.0</td><td>mclaren-ford</td><td>McLaren-Ford</td><td>British</td></tr><tr><td>21</td><td>142.0</td><td>arrows</td><td>Arrows</td><td>British</td></tr><tr><td>196</td><td>130.0</td><td>matra-ford</td><td>Matra-Ford</td><td>French</td></tr><tr><td>113</td><td>130.0</td><td>kurtis_kraft</td><td>Kurtis Kraft</td><td>American</td></tr><tr><td>118</td><td>108.0</td><td>vanwall</td><td>Vanwall</td><td>British</td></tr><tr><td>167</td><td>83.0</td><td>cooper-maserati</td><td>Cooper-Maserati</td><td>British</td></tr><tr><td>59</td><td>79.0</td><td>wolf</td><td>Wolf</td><td>Canadian</td></tr><tr><td>183</td><td>78.0</td><td>brabham-climax</td><td>Brabham-Climax</td><td>British</td></tr><tr><td>182</td><td>68.0</td><td>brabham-ford</td><td>Brabham-Ford</td><td>British</td></tr><tr><td>58</td><td>59.0</td><td>shadow</td><td>Shadow</td><td>British</td></tr><tr ...

# %%
#O Bronze -> Silver -> Gold

# %%
#Foram usados Os comandos Sqls simples

# %%
# =========================
# SILVER
# =========================

silver_drivers_df = bronze_drivers_df \
    .withColumnRenamed("forename", "nome") \
    .withColumnRenamed("surname", "sobrenome") \
    .drop("url")

dbutils.fs.rm(
    "/Volumes/workspace/f1_proje/f1_data/silver/drivers",
    True
)

silver_drivers_df.write.format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save("/Volumes/workspace/f1_proje/f1_data/silver/drivers")

# =========================
# GOLD
# =========================

gold_driver_ranking_df = silver_drivers_df.groupBy(
    "nationality"
).count()

dbutils.fs.rm(
    "/Volumes/workspace/f1_proje/f1_data/gold/driver_ranking",
    True
)

gold_driver_ranking_df.write.format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .save("/Volumes/workspace/f1_proje/f1_data/gold/driver_ranking")

print("Pipeline executado com sucesso")
